# %%
import pandas as pd
import scipy.stats as st
import seaborn as sns

data= pd.read_csv("Heart_Disease_Prediction.csv")
data.info()
data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270 entries, 0 to 269
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      270 non-null    int64
#  1   Sex                      270 non-null    int64
#  2   Chest pain type          270 non-null    int64
#  3   BP                       270 non-null    int64
#  4   Cholesterol              270 non-null    int64
#  5   FBS over 120             270 non-null    int64
#  6   EKG results              270 non-null    int64
#  7   Max HR                   270 non-null    int64
#  8   Exercise angina          270 non-null    int64
#  9   ST depression            270 non-null    float64
#  10  Slope of ST              270 non-null    int64
#  11  Number of vessels fluro  270 non-null    int64
#  12  Thallium                 270 non-null    int64
#  13  Heart Disease            270 non-null    object
# ...

# %%
#Plot scatter Plot
data.plot(kind='scatter',x="Age",y="BP")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='BP'>

# %%
list(data.columns)
# Out:
# ['Age',
#  'Sex',
#  'Chest pain type',
#  'BP',
#  'Cholesterol',
#  'FBS over 120',
#  'EKG results',
#  'Max HR',
#  'Exercise angina',
#  'ST depression',
#  'Slope of ST',
#  'Number of vessels fluro',
#  'Thallium',
#  'Heart Disease']

# %%
#to ctreate line of best fit
sns.lmplot(x="Age", y="BP",data=data);

# %%
#to calculate pearson r coefficient
st.pearsonr(data['BP'], data['Cholesterol'])
# Out:
# (0.17301917553469248, 0.004353535732681628)

# %%
#create correlation matrix
#A correlation matrix is a handy way to calculate the pairwise correlation coefficients between two or more (numeric) variables
cormat = data.corr()
round(cormat,2)
# Out:
#                           Age   Sex  Chest pain type    BP  Cholesterol  \
# Age                      1.00 -0.09             0.10  0.27         0.22
# Sex                     -0.09  1.00             0.03 -0.06        -0.20
# Chest pain type          0.10  0.03             1.00 -0.04         0.09
# BP                       0.27 -0.06            -0.04  1.00         0.17
# Cholesterol              0.22 -0.20             0.09  0.17         1.00
# FBS over 120             0.12  0.04            -0.10  0.16         0.03
# EKG results              0.13  0.04             0.07  0.12         0.17
# Max HR                  -0.40 -0.08            -0.32 -0.04        -0.02
# Exercise angina          0.10  0.18             0.35  0.08         0.08
# ST depression            0.19  0.10             0.17  0.22         0.03
# Slope of ST              0.16  0.05             0.14  0.14        -0.01
# Number of vessels fluro  0.36  0.09             0.23  0.09         0.13
# ...

# %%
#create heatmap
sns.heatmap(cormat);

# %%
data.plot(kind='scatter',x="Age",y="ST depression")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='ST depression'>

# %%
data.plot(kind='scatter',x="Sex",y="Cholesterol")
sns.lmplot(x="Sex", y="Cholesterol",data=data);

# %%
#Show row percentages
conttab_relfreq = pd.crosstab(
    data['Age'],
    data['Sex'],
    margins = True,
    normalize='index'
   )
conttab_relfreq
# Out:
# Sex         0         1
# Age
# 29   0.000000  1.000000
# 34   0.500000  0.500000
# 35   0.333333  0.666667
# 37   0.500000  0.500000
# 38   0.000000  1.000000
# 39   0.333333  0.666667
# 40   0.000000  1.000000
# 41   0.444444  0.555556
# 42   0.250000  0.750000
# 43   0.285714  0.714286
# 44   0.200000  0.800000
# 45   0.428571  0.571429
# 46   0.428571  0.571429
# 47   0.000000  1.000000
# 48   0.142857  0.857143
# 49   0.400000  0.600000
# 50   0.428571  0.571429
# 51   0.333333  0.666667
# 52   0.090909  0.909091
# 53   0.285714  0.714286
# 54   0.312500  0.687500
# 55   0.333333  0.666667
# 56   0.333333  0.666667
# 57   0.166667  0.833333
# 58   0.266667  0.733333
# 59   0.083333  0.916667
# 60   0.416667  0.583333
# 61   0.285714  0.714286
# 62   0.636364  0.363636
# 63   0.571429  0.428571
# 64   0.333333  0.666667
# 65   0.500000  0.500000
# 66   0.333333  0.666667
# 67   0.375000  0.625000
# 68   0.333333  0.666667
# 69   0.333333  0.666667
# 70   0.000000  1.000000
# ...

# %%
#Chi square test of independence
contab_obs = pd.crosstab(
    data['Age'],
    data['BP'],
    margins = False)
chi = st.chi2_contingency(contab_obs)
chi
# Out:
# (1648.9652017911935,
#  0.9994312965688293,
#  1840,
#  array([[0.00740741, 0.01481481, 0.0037037 , ..., 0.01111111, 0.0037037 ,
#          0.0037037 ],
#         [0.01481481, 0.02962963, 0.00740741, ..., 0.02222222, 0.00740741,
#          0.00740741],
#         [0.02222222, 0.04444444, 0.01111111, ..., 0.03333333, 0.01111111,
#          0.01111111],
#         ...,
#         [0.00740741, 0.01481481, 0.0037037 , ..., 0.01111111, 0.0037037 ,
#          0.0037037 ],
#         [0.00740741, 0.01481481, 0.0037037 , ..., 0.01111111, 0.0037037 ,
#          0.0037037 ],
#         [0.00740741, 0.01481481, 0.0037037 , ..., 0.01111111, 0.0037037 ,
#          0.0037037 ]]))
